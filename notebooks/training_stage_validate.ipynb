# %%
import os
import sys
import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
acc = pd.read_csv('run_.-tag-acc.csv')
val_acc = pd.read_csv('run_.-tag-val_acc.csv')
loss = pd.read_csv('run_.-tag-loss.csv')
val_loss = pd.read_csv('run_.-tag-val_loss.csv')

# %%
plt.plot(acc['Step'][:30], acc['Value'][:30], label='acc')
plt.plot(val_acc['Step'][:30], val_acc['Value'][:30], label='val_acc')
plt.title("Acc and val_acc")
plt.xlabel("Epoch")
plt.ylabel("percentage")
plt.legend()
plt.grid()

# %%
plt.plot(loss['Step'][:30], loss['Value'][:30], label='loss')
plt.plot(val_loss['Step'][:30], val_loss['Value'][:30], label='val_loss')
plt.title("Loss and val_loss")
plt.xlabel("Epoch")
plt.ylabel("Value")
plt.legend()
plt.grid()

# %%
def pickle_load(in_file):
    with open(in_file, "rb") as opened_file:
        return pickle.load(opened_file)

# %%
a = pickle_load("../output/training_ids.pkl")
len(a)
# Out:
# 219
